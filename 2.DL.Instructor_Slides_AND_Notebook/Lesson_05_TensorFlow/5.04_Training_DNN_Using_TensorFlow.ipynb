# %% [markdown]
# # 🏠 **Training Deep Neural Networks on TensorFlow**
# # **Predicting House Prices with Regression Models**
#
# ---
#
# ## 🎓 **Learning Objectives**
#
# By the end of this lesson, you will be able to:
#
# ✅ Build **regression models** for continuous value prediction
# ✅ Work with the **California Housing dataset** (real-world data)
# ✅ Implement **feature standardization** for better performance
# ✅ Use **Early Stopping** to prevent overfitting
# ✅ Monitor training with **custom callbacks**
# ✅ Understand **validation splits** and their importance
# ✅ Evaluate models using **Mean Absolute Error (MAE)**
# ✅ Compare **classification vs regression** neural networks
#
# ---
#
# ## 📚 **Prerequisites**
#
# Before starting this lesson, you should:
#
# - ✅ Understand basic neural network concepts (Lessons 3-4)
# - ✅ Be familiar with TensorFlow/Keras (Lesson 5.02-5.03)
# - ✅ Know about classification models (MNIST example)
# - ✅ Understand train/test splits
# - ✅ Be comfortable with NumPy and Pandas
#
# **Estimated Time:** 2-3 hours
#
# ---
#
# ## 📋 **What You'll Learn**
#
# ### **Part 1: Regression vs Classification**
# - Key differences
# - When to use each
# - Output layer design
# - Loss function selection
#
# ### **Part 2: California Housing Dataset**
# - Dataset characteristics
# - Feature engineering
# - Standardization importance
# - Train/validation/test splits
#
# ### **Part 3: Model Architecture for Regression**
# - Dense layers for regression
# - Activation function choices
# - Output layer (single neuron, no activation)
# - Optimizer and loss function
#
# ### **Part 4: Advanced Training Techniques**
# - Early stopping callback
# - Custom progress indicators
# - Validation monitoring
# - Performance evaluation
#
# ---
#
# ## 🌟 **Why This Matters**
#
# **Regression is EVERYWHERE in real-world applications!**
#
# ### **Real-World Regression Problems:**
#
# 1. **🏠 Real Estate:**
#    - House price prediction
#    - Rent estimation
#    - Property valuation
#
# 2. **📈 Finance:**
#    - Stock price forecasting
#    - Revenue prediction
#    - Risk assessment
#
# 3. **🌡️ Science & Engineering:**
#    - Temperature prediction
#    - Energy consumption forecasting
#    - Material property estimation
#
# 4. **🚗 Transportation:**
#    - Travel time estimation
#    - Fuel consumption prediction
#    - Traffic flow forecasting
#
# 5. **🏥 Healthcare:**
#    - Patient recovery time
#    - Treatment cost estimation
#    - Disease progression prediction
#
# **Industry Impact:**
# - Zillow uses similar models for home valuation
# - Uber estimates fare prices
# - Energy companies predict demand
#
# ---
#
# ## 🆚 **Regression vs Classification**
#
# Understanding the difference is CRITICAL!
#
# | Aspect | **Regression** | **Classification** |
# |--------|---------------|-------------------|
# | **Output** | Continuous value | Discrete class |
# | **Example** | House price: $450,000 | Digit: 5 |
# | **Output Layer** | Single neuron (or n for multi-output) | n neurons (n classes) |
# | **Activation** | None (linear) or ReLU | Softmax |
# | **Loss** | MSE, MAE, Huber | CrossEntropy |
# | **Metric** | MAE, RMSE, R² | Accuracy, F1-score |
# | **Range** | Any real number | Probabilities [0,1] |
#
# ### **Examples:**
# ```python
# # REGRESSION (this lesson)
# Input: [location, size, bedrooms, ...]
# Output: 450000.0  (price in dollars)
#
# # CLASSIFICATION (previous lesson)
# Input: [28×28 pixel image]
# Output: [0.01, 0.02, ..., 0.89, ...]  (probabilities for digits 0-9)
# ```
#
# ---
#
# ## 🏠 **The California Housing Dataset**
#
# ### **Dataset Overview:**
#
# **Source:** 1990 California census data
# **Purpose:** Predict median house values
#
# **Statistics:**
# - **Samples:** 20,640 housing blocks
# - **Features:** 8 numerical features
# - **Target:** Median house value (in $100,000s)
#
# ### **Features:**
#
# 1. **MedInc** - Median income in block ($10,000s)
# 2. **HouseAge** - Median house age in block (years)
# 3. **AveRooms** - Average number of rooms per household
# 4. **AveBedrms** - Average number of bedrooms per household
# 5. **Population** - Block population
# 6. **AveOccup** - Average household occupancy
# 7. **Latitude** - Block latitude
# 8. **Longitude** - Block longitude
#
# ### **Target Variable:**
# - **Median house value** in $100,000s
# - Range: ~$15k to $500k+
# - California-specific (high prices!)
#
# ### **Challenge:**
# Can a neural network learn the relationship between these features and house prices?
#
# ---
#
# ## 🎯 **Model Architecture for Regression**
#
# ```
# INPUT (8 features)
#     ↓
# STANDARDIZATION (mean=0, std=1)
#     ↓
# DENSE (20 neurons, ReLU)
#     ↓
# DENSE (1 neuron, Linear)
#     ↓
# OUTPUT (house price)
# ```
#
# ### **Key Design Decisions:**
#
# **1. Input Standardization:**
# - Features have different scales
# - MedInc: 0-15, Latitude: 32-42
# - Standardize to mean=0, std=1
#
# **2. Hidden Layer (20 neurons):**
# - Learns non-linear relationships
# - ReLU activation (standard choice)
# - Enough capacity for 8 features
#
# **3. Output Layer (1 neuron):**
# - **No activation** (linear output)
# - Can predict any real number
# - Direct price prediction
#
# **4. Loss Function (MAE):**
# - Mean Absolute Error
# - Easy to interpret (average $ error)
# - Robust to outliers
#
# ---
#
# ## 📊 **Training Strategy**
#
# ### **Data Split:**
# ```
# Full Dataset (20,640 samples)
#     ↓
# Train: 80% (16,512)
#     ↓
#     ├─ Training: 90% (14,861)
#     └─ Validation: 10% (1,651)
# Test: 20% (4,128)
# ```
#
# ### **Early Stopping:**
# - Monitor validation loss
# - Stop if no improvement for 50 epochs
# - Prevents overfitting
# - Saves training time
#
# ### **Custom Callback:**
# - Visual progress indicator
# - Prints dot per epoch
# - Newline every 100 epochs
# - User-friendly feedback
#
# ---
#
# Let's build a house price predictor! 🚀

# %% [markdown]
# ## Steps to be followed:
# 1. Import the required libraries
# 2. Load and inspect the data
# 3. Build the model
# 4. Train the model

# %% [markdown]
# ### Step 1: Import the required libraries
#
# - Import Pandas and NumPy packages.
# - Import the TensorFlow package, which is used for text-based applications, image recognition, voice search, and many more.
# - Import the Python package cv2, which is used for computer vision and image processing.
# - Import the Python package matplotlib, which sets the padding between and around the subplots as well as the figure size.
# - Import necessary libraries and modules for building a deep learning model using TensorFlow. It includes modules for convolutional and pooling layers, dropout, flattening, and dense layers.
# - Import other libraries for data manipulation, visualization, and image processing.

# %%
# !pip install tensorflow==2.17.0 scikeras==0.13.0 keras==3.2.0
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow==2.17.0 in /voc/work/.local/lib/python3.10/site-packages (2.17.0)
# Requirement already satisfied: scikeras==0.13.0 in /voc/work/.local/lib/python3.10/site-packages (0.13.0)
# Requirement already satisfied: keras==3.2.0 in /voc/work/.local/lib/python3.10/site-packages (3.2.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/site-packages (from tensorflow==2.17.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/site-packages (from tensorflow==2.17.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /voc/work/.local/lib/python3.10/site-packages (from tensorflow==2.17.0) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/site-packages (from tensorflow==2.17.0) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/site-packages (from tensorflow==2.17.0) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /voc/work/.local/lib/python3.10/site-packages (from tensorflow==2.17.0) (3.14.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/site-packages (from tensorflow==2.17.0) (14.0.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /voc/work/.local/lib/python3.10/site-packages (from tensorflow==2.17.0) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/site-packages (from tensorflow==2.17.0) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/site-packages (from tensorflow==2.17.0) (22.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /voc/work/.local/lib/python3.10/site-packages (from tensorflow==2.17.0) (4.25.7)
# Requirement already satisfied: requests<3,>=2.21.0 in /voc/work/.local/lib/python3.10/site-packages (from tensorflow==2.17.0) (2.32.5)
# Requirement already satisfied: setuptools in /voc/work/.local/lib/python3.10/site-packages (from tensorflow==2.17.0) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in /voc/work/.local/lib/python3.10/site-packages (from tensorflow==2.17.0) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/site-packages (from tensorflow==2.17.0) (1.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /voc/work/.local/lib/python3.10/site-packages (from tensorflow==2.17.0) (4.13.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/site-packages (from tensorflow==2.17.0) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /voc/work/.local/lib/python3.10/site-packages (from tensorflow==2.17.0) (1.71.0)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /voc/work/.local/lib/python3.10/site-packages (from tensorflow==2.17.0) (2.17.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/site-packages (from tensorflow==2.17.0) (0.26.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /voc/work/.local/lib/python3.10/site-packages (from tensorflow==2.17.0) (1.26.4)
# Requirement already satisfied: scikit-learn>=1.4.2 in /voc/work/.local/lib/python3.10/site-packages (from scikeras==0.13.0) (1.7.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/site-packages (from keras==3.2.0) (13.5.3)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/site-packages (from keras==3.2.0) (0.0.7)
# Requirement already satisfied: optree in /voc/work/.local/lib/python3.10/site-packages (from keras==3.2.0) (0.17.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow==2.17.0) (0.37.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /voc/work/.local/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow==2.17.0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow==2.17.0) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /voc/work/.local/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow==2.17.0) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /voc/work/.local/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow==2.17.0) (2025.4.26)
# Requirement already satisfied: scipy>=1.8.0 in /voc/work/.local/lib/python3.10/site-packages (from scikit-learn>=1.4.2->scikeras==0.13.0) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /voc/work/.local/lib/python3.10/site-packages (from scikit-learn>=1.4.2->scikeras==0.13.0) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /voc/work/.local/lib/python3.10/site-packages (from scikit-learn>=1.4.2->scikeras==0.13.0) (3.6.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/site-packages (from tensorboard<2.18,>=2.17->tensorflow==2.17.0) (3.3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/site-packages (from tensorboard<2.18,>=2.17->tensorflow==2.17.0) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/site-packages (from tensorboard<2.18,>=2.17->tensorflow==2.17.0) (2.1.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/site-packages (from rich->keras==3.2.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/site-packages (from rich->keras==3.2.0) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras==3.2.0) (0.1.1)

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# %%
import os

# Disable oneDNN optimizations to avoid potential minor numerical differences caused by floating-point round-off errors.
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'

# %%
# Import TensorFlow and required layers for building the model
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense

# Import other necessary libraries for data manipulation, visualization, and image processing
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import os
import sys
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import cv2
import IPython
from six.moves import urllib

# %% [markdown]
# ### Step 2: Load and inspect the data
#
#
# - Load the California Housing dataset from **`fetch_california_housing`**.
# - Split the dataset into two sets: the training set **train_features** and **train_labels** and the testing set **test_features** and **test_labels**.
# - The testing set is used to evaluate the trained model's performance.

# %%
# Load the California Housing dataset from sklearn
from sklearn.datasets import fetch_california_housing
housing = fetch_california_housing()

# Convert to pandas DataFrame
data = pd.DataFrame(housing.data, columns=housing.feature_names)
data['target'] = housing.target

# Split the dataset into training and testing sets
train_data, test_data, train_labels, test_labels = train_test_split(data[housing.feature_names], data['target'], test_size=0.2, random_state=42)

# %%
# Standardize the features
scaler = StandardScaler()
train_features = scaler.fit_transform(train_data)
test_features = scaler.transform(test_data)

# Print the standardized training features
print(train_features)
# Out:
# [[-0.326196    0.34849025 -0.17491646 ...  0.05137609 -1.3728112
#    1.27258656]
#  [-0.03584338  1.61811813 -0.40283542 ... -0.11736222 -0.87669601
#    0.70916212]
#  [ 0.14470145 -1.95271028  0.08821601 ... -0.03227969 -0.46014647
#   -0.44760309]
#  ...
#  [-0.49697313  0.58654547 -0.60675918 ...  0.02030568 -0.75500738
#    0.59946887]
#  [ 0.96545045 -1.07984112  0.40217517 ...  0.00707608  0.90651045
#   -1.18553953]
#  [-0.68544764  1.85617335 -0.85144571 ... -0.08535429  0.99543676
#   -1.41489815]]

# %% [markdown]
#  __Observation:__
#
#
# - Here, we can see a few datasets from train dataset.
# - The given array represents a multi-dimensional array containing numerical values.
# - Each row in the array corresponds to a set of features or data points, while each column represents a specific feature or variable.

# %% [markdown]
# ### Step 3: Build the Model
# Building the neural network requires:
# - Configuring the layers of the model and compiling the model.
# - Stacking a few layers together using **keras.Sequential**.
# - Configuring the loss function, optimizer, and metrics to monitor.
# These are added during the model's compile step.
#
#
#
# Terminologies:
# - The **Loss** function measures how accurate the model is during training; we want to minimize this with the optimizer.
# - One must **Optimize** how the model is updated based on the data it sees and its loss function.
# - **Metrics** are used to monitor the training and testing steps.

# %%
# Function to build the neural network model
def build_model():
    model = keras.Sequential([
        # Input layer with 20 units and ReLU activation
        Dense(20, activation=tf.nn.relu, input_shape=[train_features.shape[1]]),
        # Output layer with 1 unit
        Dense(1)
    ])

    # Compile the model with Adam optimizer and mean absolute error loss
    model.compile(optimizer=tf.optimizers.Adam(),
                  loss='mae',
                  metrics=['mean_absolute_error'])
    return model

# %% [markdown]
# ### Step 4: Train the model
# Training the neural network model requires the following steps:
#
#
# - Define a custom callback class **PrintDot**, which prints a dot for every epoch during training.
#
#   `PrintDot` is a custom callback class in Keras that is used to provide visual feedback during the training process of a neural network. It prints a dot (.) for every epoch completed, and it prints a new line every 100 epochs. This helps in monitoring the progress of the training process in a simple and visual way without overwhelming the console with too much information.
#
# - Create an instance of the model using the **build_model** function.
#
# - Create an instance of EarlyStopping callback, which monitors the validation loss and stops training if it doesn't improve after a certain number of epochs (specified by patience).
#
# - Train the model using the training features and labels. It runs for 200 epochs, with a validation split of 0.1 (10% of the training data used for validation). The callbacks parameter includes **early_stop** and **PrintDot** callbacks.
#
# - Create a Pandas **DataFrame hist** from the history object returned by the model.fit method. It contains the recorded training and validation metrics.
#
# - Extract the last value of the validation mean absolute error (MAE) from the hist DataFrame and assign it to the variable mae_final.
#
# - Print the final MAE on the validation set, rounded to three decimal places.

# %%
# Custom callback class to print a dot for every epoch
class PrintDot(keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs):
        if epoch % 100 == 0: print('')
        print('.', end='')

# Build the model using the build_model function
model = build_model()

# Early stopping callback to stop training if validation loss doesn't improve for 50 epochs
early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=50)

# Train the model with training data, using 10% of the data for validation
history = model.fit(train_features, train_labels, epochs=200, verbose=0, validation_split=0.1,
                    callbacks=[early_stop, PrintDot()])

# Create a Pandas DataFrame from the training history
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch

# Extract the final mean absolute error from the validation set
mae_final = float(hist['val_mean_absolute_error'].iloc[-1])

print()
print('Final Mean Absolute Error on validation set: {}'.format(round(mae_final, 3)))
# Out:
# /voc/work/.local/lib/python3.10/site-packages/keras/src/layers/core/dense.py:86: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# ....................................................................................................
# ....................................................................................................
# Final Mean Absolute Error on validation set: 0.376

# %% [markdown]
# **Observation:**
#
# As shown, the final mean absolute error on the validation set is 0.381.

# %% [markdown]
# - Evaluate the model's performance on the normalized test features and prints the mean absolute error (MAE) on the test set.

# %%
# Evaluate the model's performance on the test set
mae, _ = model.evaluate(test_features, test_labels)
print('Mean Absolute Error on test set: {}'.format(round(mae, 3)))
# Out:
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 478us/step - loss: 0.3697 - mean_absolute_error: 0.3697
# Mean Absolute Error on test set: 0.373

# %% [markdown]
# **Observation:**
#
# The output indicates the following:
#
# - The evaluation was performed on the `test_features` and `test_labels`.
# - The mean absolute error on the test set is also 0.3704.
# - The mean absolute error, when rounded, is 0.373.

# %% [markdown]
# ---
#
# ## 🎓 **Key Takeaways & Summary**
#
# ### **What We Accomplished:**
#
# ✅ Built **regression model** for continuous value prediction
# ✅ Trained on **California Housing** dataset (20,640 samples)
# ✅ Implemented **early stopping** to prevent overfitting
# ✅ Used **validation split** for proper evaluation
# ✅ Achieved **MAE ~0.37** (average error of $37,000)
# ✅ Mastered complete **regression workflow**
#
# ---
#
# ### **Core Concepts:**
#
# **1. Regression vs Classification:**
# - Regression: Predict continuous values (house prices)
# - Classification: Predict discrete classes (digit labels)
# - Different output layers, activations, loss functions
#
# **2. Model Architecture:**
# ```python
# Sequential([
#     Dense(20, activation='relu'),  # Hidden layer
#     Dense(1)                        # Output: linear (no activation)
# ])
# ```
#
# **3. Training Techniques:**
# - Standardization: Essential for convergence
# - Early stopping: Prevents overfitting
# - Validation split: Monitors generalization
# - Custom callbacks: User feedback
#
# ---
#
# ### **🚀 Next Steps:**
#
# 1. **Lesson 5.09:** Sequential APIs (model building patterns)
# 2. **Lesson 5.10:** Functional APIs (complex architectures)
# 3. **Lesson 8:** CNNs (image-specific architectures)
#
# **Practice:** Try deeper networks, different optimizers, feature engineering!
#
# ---
#
# ## 🏆 **Great Work!**
#
# You can now build regression models for real-world prediction tasks! 🎉
